# %% [markdown]
# # Visualisation for all graphs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Arial"
})

# %%
def set_dataset(filename):
    data = []
    for file in glob.glob("../" + filename + "/computation*.csv"):
        data.append(pd.read_csv(file, delimiter=',', ))
    data = pd.concat(data)
    data = data.reset_index(drop=True)
    return data

# %%
data = set_dataset("data")
bdata = set_dataset("bdata")
rdata = set_dataset("rdata")
idata = set_dataset("idata/_")
ibdata = set_dataset("idata/b")
# irdata = set_dataset("idata/r")

# %%
data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()
# Out:
# /tmp/ipykernel_8125/2688302214.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_8125/2688302214.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_8125/2688302214.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])

# %%
data.boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()

# %%
bdata[bdata.dist_victim_relayer>=0][bdata.FreeNet_delta_ranks>=0][bdata.Reversed_delta_ranks>=0][bdata.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()
# Out:
# /tmp/ipykernel_8125/3721090167.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bdata[bdata.dist_victim_relayer>=0][bdata.FreeNet_delta_ranks>=0][bdata.Reversed_delta_ranks>=0][bdata.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_8125/3721090167.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bdata[bdata.dist_victim_relayer>=0][bdata.FreeNet_delta_ranks>=0][bdata.Reversed_delta_ranks>=0][bdata.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_8125/3721090167.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bdata[bdata.dist_victim_relayer>=0][bdata.FreeNet_delta_ranks>=0][bdata.Reversed_delta_ranks>=0][bdata.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])

# %%
bdata.boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()

# %%
rdata[rdata.dist_victim_relayer>=0][rdata.FreeNet_delta_ranks>=0][rdata.Reversed_delta_ranks>=0][rdata.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()

# %%
rdata.boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.show()

# %%
# Plot
fig, axes = plt.subplots(1, 3, figsize=(7, 3))

# data.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[0])
axes[0].violinplot(
    [
        data.FreeNet_delta_ranks,
        data.Reversed_delta_ranks,
        data.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[0].set_xticks([1, 2, 3])
axes[0].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[0].set_title("$D^\mathrm{BA}_{100}$")
axes[0].tick_params(axis='x', labelrotation=90)


# bdata.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[1])
axes[1].violinplot(
    [
        bdata.FreeNet_delta_ranks,
        bdata.Reversed_delta_ranks,
        bdata.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[1].set_xticks([1, 2, 3])
axes[1].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[1].set_title("$D^\mathrm{BA}_{1000}$")
axes[1].tick_params(axis='x', labelrotation=90)


axes[2].violinplot(
    [
        rdata.FreeNet_delta_ranks,
        rdata.Reversed_delta_ranks,
        rdata.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[2].set_xticks([1, 2, 3])
axes[2].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[2].set_title("$D^\mathrm{NS}_{907}$")
axes[2].tick_params(axis='x', labelrotation=90)

# rdata.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[2])
# axes[2].set_title("Third graph computation")
# axes[2].tick_params(axis='x', labelrotation=90)

# --- Right: Weak scaling ---

# Final formatting
plt.tight_layout()

plt.savefig("plots/all.pdf")
plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:47: SyntaxWarning: invalid escape sequence '\D'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# <>:49: SyntaxWarning: invalid escape sequence '\D'
# <>:52: SyntaxWarning: invalid escape sequence '\m'
# <>:72: SyntaxWarning: invalid escape sequence '\D'
# <>:73: SyntaxWarning: invalid escape sequence '\D'
# <>:74: SyntaxWarning: invalid escape sequence '\D'
# <>:77: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:47: SyntaxWarning: invalid escape sequence '\D'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# ...

# %%
# Plot
fig, axes = plt.subplots(1, 3, figsize=(5, 3))


data_filtered = data[
    (data["dist_victim_relayer"] >= 0) &
    (data["FreeNet_delta_ranks"] >= 0) &
    (data["Reversed_delta_ranks"] >= 0) &
    (data["Random_delta_ranks"] >= 0)
]
bdata_filtered = bdata[
    (data["dist_victim_relayer"] >= 0) &
    (data["FreeNet_delta_ranks"] >= 0) &
    (data["Reversed_delta_ranks"] >= 0) &
    (data["Random_delta_ranks"] >= 0)
]
rdata_filtered = rdata[
    (data["dist_victim_relayer"] >= 0) &
    (data["FreeNet_delta_ranks"] >= 0) &
    (data["Reversed_delta_ranks"] >= 0) &
    (data["Random_delta_ranks"] >= 0)
]


# data.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[0])
axes[0].violinplot(
    [
        data_filtered.FreeNet_delta_ranks,
        data_filtered.Reversed_delta_ranks,
        data_filtered.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[0].set_xticks([1, 2, 3])
axes[0].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[0].set_title("$D^\mathrm{BA}_{100}$")
axes[0].tick_params(axis='x', labelrotation=90)


# bdata_filtered.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[1])
axes[1].violinplot(
    [
        bdata_filtered.FreeNet_delta_ranks,
        bdata_filtered.Reversed_delta_ranks,
        bdata_filtered.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[1].set_xticks([1, 2, 3])
axes[1].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[1].set_title("$D^\mathrm{BA}_{1000}$")
axes[1].tick_params(axis='x', labelrotation=90)


axes[2].violinplot(
    [
        rdata_filtered.FreeNet_delta_ranks,
        rdata_filtered.Reversed_delta_ranks,
        rdata_filtered.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[2].set_xticks([1, 2, 3])
axes[2].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[2].set_title("$D^\mathrm{RE}_{?}$")
axes[2].tick_params(axis='x', labelrotation=90)


# data_filtered.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[0])
# axes[0].set_title("First graph computation")
# axes[0].tick_params(axis='x', labelrotation=90)


# bdata_filtered.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[1])
# axes[1].set_title("Second graph computation")
# axes[1].tick_params(axis='x', labelrotation=90)


# rdata_filtered.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[2])
# axes[2].set_title("Third graph computation")
# axes[2].tick_params(axis='x', labelrotation=90)

# # --- Right: Weak scaling ---

# # Final formatting
plt.tight_layout()
# # plt.figtext(
# #     0.5,
# #     -0.05,
# #     "",
# #     wrap=True,
# #     horizontalalignment="center",
# #     fontsize=9,
# # )
plt.savefig("plots/all_positive.pdf")
plt.show()
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\D'
# <>:43: SyntaxWarning: invalid escape sequence '\D'
# <>:44: SyntaxWarning: invalid escape sequence '\D'
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# <>:68: SyntaxWarning: invalid escape sequence '\D'
# <>:69: SyntaxWarning: invalid escape sequence '\D'
# <>:70: SyntaxWarning: invalid escape sequence '\D'
# <>:73: SyntaxWarning: invalid escape sequence '\m'
# <>:93: SyntaxWarning: invalid escape sequence '\D'
# <>:94: SyntaxWarning: invalid escape sequence '\D'
# <>:95: SyntaxWarning: invalid escape sequence '\D'
# <>:98: SyntaxWarning: invalid escape sequence '\m'
# <>:42: SyntaxWarning: invalid escape sequence '\D'
# <>:43: SyntaxWarning: invalid escape sequence '\D'
# <>:44: SyntaxWarning: invalid escape sequence '\D'
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# <>:68: SyntaxWarning: invalid escape sequence '\D'
# <>:69: SyntaxWarning: invalid escape sequence '\D'
# ...

# %%
# Plot
# fig, axes = plt.subplots(1, 3, figsize=(7, 3))
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# idata.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[0])
axes[0].violinplot(
    [
        idata.FreeNet_delta_ranks,
        idata.Reversed_delta_ranks,
        idata.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[0].set_xticks([1, 2, 3])
axes[0].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[0].set_title("$D^\mathrm{BA}_{100}$")
axes[0].tick_params(axis='x', labelrotation=90)


# ibdata.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[1])
axes[1].violinplot(
    [
        ibdata.FreeNet_delta_ranks,
        ibdata.Reversed_delta_ranks,
        ibdata.Random_delta_ranks
    ],
    # tick_labels = [
    #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
    #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    # ],
)
axes[1].set_xticks([1, 2, 3])
axes[1].set_xticklabels(
    [

        "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
        "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
    ],
)
axes[1].set_title("$D^\mathrm{BA}_{1000}$")
axes[1].tick_params(axis='x', labelrotation=90)


# axes[2].violinplot(
#     [
#         irdata.FreeNet_delta_ranks,
#         irdata.Reversed_delta_ranks,
#         irdata.Random_delta_ranks
#     ],
#     # tick_labels = [
#     #     "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
#     #     "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
#     #     "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
#     # ],
# )
# axes[2].set_xticks([1, 2, 3])
# axes[2].set_xticklabels(
#     [

#         "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
#         "$\Delta^{\mathrm{Rev}}_{\mathrm{rank}}$",
#         "$\Delta^{\mathrm{PPR}}_{\mathrm{rank}}$",
#     ],
# )
# axes[2].set_title("$D^\mathrm{NS}_{907}$")
# axes[2].tick_params(axis='x', labelrotation=90)

# irdata.boxplot(column=['FreeNet_delta_ranks','Reversed_delta_ranks','Random_delta_ranks'],ax=axes[2])
# axes[2].set_title("Third graph computation")
# axes[2].tick_params(axis='x', labelrotation=90)

# --- Right: Weak scaling ---

# Final formatting
plt.tight_layout()

plt.savefig("plots/all.pdf")
plt.show()
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# <>:49: SyntaxWarning: invalid escape sequence '\D'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:53: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# <>:49: SyntaxWarning: invalid escape sequence '\D'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:53: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_1843/368714215.py:22: SyntaxWarning: invalid escape sequence '\D'
#   "$\Delta^{\mathrm{FreeNet}}_{\mathrm{rank}}$",
# ...
