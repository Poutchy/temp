# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Arial"
})

plot_save = "plots/data/"

# %%
data = []
for file in glob.glob("data/computation*.csv"):
  #print(file)
  data.append(pd.read_csv(file, delimiter=',', ))
data = pd.concat(data)
data = data.reset_index(drop=True)

#print(len(data))

#display(data.head(5))

# %%
data.boxplot(column=['FreeNet_pre_rank', 'FreeNet_post_rank', 'FreeNet_delta_ranks'])
plt.savefig(fname=plot_save + "freenet_rank.png")
plt.show()

# %%
data.boxplot(column=['Reversed_pre_rank', 'Reversed_post_rank', 'Reversed_delta_ranks'])
plt.savefig(fname=plot_save + "reversed_rank.png")
plt.show()

# %%
data[data.dist_victim_relayer>=0].boxplot(column=['Independent_pre_rank', 'Independent_post_rank', 'Independent_delta_ranks'])
plt.savefig(fname=plot_save + "independent_rank.png")
plt.show()

# %%
data[data.dist_victim_relayer>=0].boxplot(column=['Random_pre_rank', 'Random_post_rank', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "random_rank.png")
plt.show()

# %%
data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "all_positive_rank.png")
plt.show()
# Out:
# /tmp/ipykernel_17323/1996968748.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_17323/1996968748.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
# /tmp/ipykernel_17323/1996968748.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.dist_victim_relayer>=0][data.FreeNet_delta_ranks>=0][data.Reversed_delta_ranks>=0][data.Random_delta_ranks>=0].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])

# %%
data.boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "all_rank.png")
plt.show()

# %%
data.hist(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'], bins=20, sharey=True, sharex=True)
plt.savefig(fname=plot_save + "hist.png")
plt.show()

# %%
data.groupby('dist_victim_relayer').boxplot(column='FreeNet_delta_ranks')
plt.savefig(fname=plot_save + "dist_freenet.png")
plt.show()

# %%
data.groupby('dist_victim_relayer').boxplot(column='Reversed_delta_ranks')
plt.savefig(fname=plot_save + "dist_reversed.png")
plt.show()

# %%
data.groupby('dist_victim_relayer').boxplot(column='Independent_delta_ranks')
plt.savefig(fname=plot_save + "dist_independent.png")
plt.show()

# %%
data.groupby('dist_victim_relayer').boxplot(column='Random_delta_ranks')
plt.savefig(fname=plot_save + "dist_random.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_pre').boxplot(column='FreeNet_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_pre_freenet.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_pre').boxplot(column='Reversed_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_pre_reversed.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_pre').boxplot(column='Independent_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_pre_independent.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_pre').boxplot(column='Random_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_pre_random.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_pre').boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "dist_vv_pre_all.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_post').boxplot(column='FreeNet_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_post_freenet.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_post').boxplot(column='Reversed_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_post_reversed.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_post').boxplot(column='Independent_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_post_independent.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_post').boxplot(column='Random_delta_ranks')
plt.savefig(fname=plot_save + "dist_vv_post_random.png")
plt.show()

# %%
data.groupby('dist_victim_vilain_post').boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "dist_vv_post_all.png")
plt.show()

# %%
data[data.dist_victim_vilain_post == 2].boxplot(column='FreeNet_delta_ranks')
plt.savefig(fname=plot_save + "direct_attack_freenet.png")
plt.show()

# %%
data[data.dist_victim_vilain_post == 2].boxplot(column='Reversed_delta_ranks')
plt.savefig(fname=plot_save + "direct_attack_reversed.png")
plt.show()

# %%
data[data.dist_victim_vilain_post == 2].boxplot(column='Independent_delta_ranks')
plt.savefig(fname=plot_save + "direct_attack_independent.png")
plt.show()

# %%
data[data.dist_victim_vilain_post == 2].boxplot(column='Random_delta_ranks')
plt.savefig(fname=plot_save + "direct_attack_random.png")
plt.show()

# %%
data[data.dist_victim_vilain_post != 2].boxplot(column='FreeNet_delta_ranks')
plt.savefig(fname=plot_save + "indirect_attack_freenet.png")
plt.show()

# %%
data[data.dist_victim_vilain_post != 2].boxplot(column='Reversed_delta_ranks')
plt.savefig(fname=plot_save + "indirect_attack_reversed.png")
plt.show()

# %%
data[data.dist_victim_vilain_post != 2].boxplot(column='Independent_delta_ranks')
plt.savefig(fname=plot_save + "indirect_attack_independent.png")
plt.show()

# %%
data[data.dist_victim_vilain_post != 2].boxplot(column='Random_delta_ranks')
plt.savefig(fname=plot_save + "indirect_attack_random.png")
plt.show()

# %%
data[data.dist_victim_vilain_pre != data.dist_victim_vilain_post].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "different_distance_all.png")
plt.show()

# %%
data[data.dist_victim_vilain_pre == data.dist_victim_vilain_post].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "same_distance_all.png")
plt.show()

# %%
plt.scatter(x=data.out_deg_victim, y=data.FreeNet_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "out_scatter_freenet.png")
plt.show()

# %%
plt.scatter(x=data.out_deg_victim, y=data.Reversed_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "out_scatter_reversed.png")
plt.show()

# %%
plt.scatter(x=data.out_deg_victim, y=data.Independent_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "out_scatter_independent.png")
plt.show()

# %%
plt.scatter(x=data.out_deg_victim, y=data.Random_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "out_scatter_random.png")
plt.show()

# %%
plt.scatter(x=data.in_deg_villain, y=data.FreeNet_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "in_scatter_freenet.png")
plt.show()

# %%
plt.scatter(x=data.in_deg_villain, y=data.Reversed_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "in_scatter_reversed.png")
plt.show()

# %%
plt.scatter(x=data.in_deg_villain, y=data.Independent_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "in_scatter_independent.png")
plt.show()

# %%
plt.scatter(x=data.in_deg_villain, y=data.Random_delta_ranks, alpha=0.01)
plt.savefig(fname=plot_save + "in_scatter_random.png")
plt.show()

# %%
data[data.dist_victim_relayer == 1].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'])
plt.savefig(fname=plot_save + "clear_all_rank.png")
plt.show()

# %%
data[data.dist_victim_vilain_pre != data.dist_victim_vilain_post].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'], whis=(1,99))
plt.savefig(fname=plot_save + "different_distance_all.png")
plt.show()

# %%
data[data.dist_victim_vilain_pre == data.dist_victim_vilain_post].boxplot(column=['FreeNet_delta_ranks', 'Reversed_delta_ranks', 'Independent_delta_ranks', 'Random_delta_ranks'], whis=(1,99))
plt.savefig(fname=plot_save + "same_distance_all.png")
plt.show()

# %%
boxplot pour direct et indirect attack
rewritte paper
# Out:
#   Cell In[45], line 1
#     boxplot pour direct et indirect attack
#             ^
# SyntaxError: invalid syntax
